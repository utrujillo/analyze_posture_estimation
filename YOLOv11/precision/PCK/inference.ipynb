# %% [markdown]
# # Calculo de PCK's
# Nota: El PCK (Percentage of Correct Keypoints) es una métrica que mide la precisión de la estimación de postura. Compara las coordenadas predichas de los puntos clave con las coordenadas verdaderas (ground truth) y cuenta cuántos puntos clave están dentro de un umbral de distancia.
#
# ![pck](pck.png)

# %%
import os
import importlib , pck, pandas as pd # Importar importlib para recargar módulos
from dotenv import load_dotenv

dotenv_path = os.path.join(os.getcwd(), '..', '.env')
importlib.reload(pck)
from pck import PCK

# Configuracion
images_path = os.path.join(os.getenv('BASE_PATH'), os.getenv('IMAGES_SUBPATH'))
labels_path = os.path.join(os.getenv('BASE_PATH'), os.getenv('LABELS_SUBPATH'))
evaluator = PCK(os.getenv('BASE_PATH'), images_path, labels_path)
thresholds = [0.1, 0.5, 0.9]

# %% [markdown]
# # Evaluando una imagen

# %%
image = 'imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg'
results = []
for threshold in thresholds:
    results = evaluator.evaluate_image(image, threshold, results)
# Out:
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg: 640x384 1 person, 78.5ms
# Speed: 2.5ms preprocess, 78.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg: 640x384 1 person, 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg: 640x384 1 person, 64.7ms
# Speed: 0.9ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9

# %% [markdown]
# # Evaluando multiples imagenes

# %%
# Obtener la lista de todas las imágenes en la carpeta
image_files = [f for f in os.listdir(images_path) if f.endswith('.jpg')]
image_files_sorted = sorted(image_files)
results = []

for image in image_files_sorted:
    for threshold in thresholds:
        results = evaluator.evaluate_image(image, threshold, results)
# Out:
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_002_jpg.rf.39766b197a04d8d1569b3e546fd07390.jpg: 640x384 1 person, 138.6ms
# Speed: 1.5ms preprocess, 138.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_002_jpg.rf.39766b197a04d8d1569b3e546fd07390.jpg: 640x384 1 person, 69.4ms
# Speed: 1.1ms preprocess, 69.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_002_jpg.rf.39766b197a04d8d1569b3e546fd07390.jpg: 640x384 1 person, 68.7ms
# Speed: 1.2ms preprocess, 68.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_003_jpg.rf.212077a70b1de84df04262b03db57f65.jpg: 640x384 1 person, 72.7ms
# Speed: 1.2ms preprocess, 72.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_003_jpg.rf.212077a70b1de84df04262b03db57f65.jpg: 640x384 1 person, 66.5ms
# Speed: 1.0ms preprocess, 66.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_003_jpg.rf.212077a70b1de84df04262b03db57f65.jpg: 640x384 1 person, 72.6ms
# Speed: 1.2ms preprocess, 72.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_004_jpg.rf.4989fa64a1816f9648b130cd037da4c0.jpg: 640x384 1 person, 71.1ms
# Speed: 1.2ms preprocess, 71.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_004_jpg.rf.4989fa64a1816f9648b130cd037da4c0.jpg: 640x384 1 person, 66.7ms
# Speed: 1.1ms preprocess, 66.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_004_jpg.rf.4989fa64a1816f9648b130cd037da4c0.jpg: 640x384 1 person, 76.4ms
# Speed: 1.2ms preprocess, 76.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_005_jpg.rf.6fa127bc74f8ab541befa56df6976a55.jpg: 640x384 1 person, 70.7ms
# Speed: 1.4ms preprocess, 70.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 13, total_pred: 17, visible_pred: 13
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_005_jpg.rf.6fa127bc74f8ab541befa56df6976a55.jpg: 640x384 1 person, 64.6ms
# Speed: 1.0ms preprocess, 64.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 13, total_pred: 17, visible_pred: 13
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_005_jpg.rf.6fa127bc74f8ab541befa56df6976a55.jpg: 640x384 1 person, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 13, total_pred: 17, visible_pred: 13
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg: 640x384 1 person, 61.8ms
# Speed: 0.9ms preprocess, 61.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg: 640x384 1 person, 61.8ms
# Speed: 1.0ms preprocess, 61.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg: 640x384 1 person, 63.4ms
# Speed: 1.1ms preprocess, 63.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_007_jpg.rf.427bc5600e403e5fbbab27a114f10306.jpg: 640x384 1 person, 66.7ms
# Speed: 1.0ms preprocess, 66.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_007_jpg.rf.427bc5600e403e5fbbab27a114f10306.jpg: 640x384 1 person, 62.1ms
# Speed: 1.0ms preprocess, 62.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_007_jpg.rf.427bc5600e403e5fbbab27a114f10306.jpg: 640x384 1 person, 61.4ms
# Speed: 1.1ms preprocess, 61.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_008_jpg.rf.00700f922d37da70606fa16130a5d9a7.jpg: 640x384 1 person, 62.2ms
# Speed: 1.0ms preprocess, 62.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 93.75, total_true: 17, visible_true: 16, total_pred: 17, visible_pred: 16
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_008_jpg.rf.00700f922d37da70606fa16130a5d9a7.jpg: 640x384 1 person, 64.2ms
# Speed: 1.1ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 16, total_pred: 17, visible_pred: 16
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_008_jpg.rf.00700f922d37da70606fa16130a5d9a7.jpg: 640x384 1 person, 63.8ms
# Speed: 1.3ms preprocess, 63.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 16, total_pred: 17, visible_pred: 16
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_009_jpg.rf.edc93a9e00958f5569e22157b0aefe83.jpg: 640x384 1 person, 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 93.75, total_true: 17, visible_true: 16, total_pred: 17, visible_pred: 16
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_009_jpg.rf.edc93a9e00958f5569e22157b0aefe83.jpg: 640x384 1 person, 64.4ms
# Speed: 0.9ms preprocess, 64.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 16, total_pred: 17, visible_pred: 16
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_009_jpg.rf.edc93a9e00958f5569e22157b0aefe83.jpg: 640x384 1 person, 63.6ms
# Speed: 1.0ms preprocess, 63.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 16, total_pred: 17, visible_pred: 16
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_010_jpg.rf.adf365bd7315f99371253648fc784b87.jpg: 640x384 1 person, 62.7ms
# Speed: 0.9ms preprocess, 62.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_010_jpg.rf.adf365bd7315f99371253648fc784b87.jpg: 640x384 1 person, 63.7ms
# Speed: 1.0ms preprocess, 63.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_010_jpg.rf.adf365bd7315f99371253648fc784b87.jpg: 640x384 1 person, 62.7ms
# Speed: 1.0ms preprocess, 62.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_011_jpg.rf.efc4f6570869d250cc6316a35f6b4b26.jpg: 640x384 1 person, 61.6ms
# Speed: 1.0ms preprocess, 61.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 80.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_011_jpg.rf.efc4f6570869d250cc6316a35f6b4b26.jpg: 640x384 1 person, 62.6ms
# Speed: 1.0ms preprocess, 62.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_011_jpg.rf.efc4f6570869d250cc6316a35f6b4b26.jpg: 640x384 1 person, 62.6ms
# Speed: 0.9ms preprocess, 62.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_012_jpg.rf.73579363caeccc19c4ce66fcc36a6b35.jpg: 640x384 1 person, 62.6ms
# Speed: 1.0ms preprocess, 62.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 90.9090909090909, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_012_jpg.rf.73579363caeccc19c4ce66fcc36a6b35.jpg: 640x384 1 person, 61.6ms
# Speed: 1.0ms preprocess, 61.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_012_jpg.rf.73579363caeccc19c4ce66fcc36a6b35.jpg: 640x384 1 person, 63.8ms
# Speed: 0.9ms preprocess, 63.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_013_jpg.rf.d8bbed7435222a80c55481d03c35ed33.jpg: 640x384 1 person, 62.4ms
# Speed: 1.4ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_013_jpg.rf.d8bbed7435222a80c55481d03c35ed33.jpg: 640x384 1 person, 60.4ms
# Speed: 1.0ms preprocess, 60.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_013_jpg.rf.d8bbed7435222a80c55481d03c35ed33.jpg: 640x384 1 person, 61.3ms
# Speed: 0.9ms preprocess, 61.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_014_jpg.rf.9b73844fd1a58e6de1dd2cd81aca8dc6.jpg: 640x384 1 person, 61.6ms
# Speed: 0.9ms preprocess, 61.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 91.66666666666666, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_014_jpg.rf.9b73844fd1a58e6de1dd2cd81aca8dc6.jpg: 640x384 1 person, 61.9ms
# Speed: 1.0ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_014_jpg.rf.9b73844fd1a58e6de1dd2cd81aca8dc6.jpg: 640x384 1 person, 61.6ms
# Speed: 1.1ms preprocess, 61.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_015_jpg.rf.f9f4a2f961f83fa157ea9589e10e6ef9.jpg: 640x384 1 person, 61.0ms
# Speed: 0.9ms preprocess, 61.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 92.3076923076923, total_true: 17, visible_true: 13, total_pred: 17, visible_pred: 13
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_015_jpg.rf.f9f4a2f961f83fa157ea9589e10e6ef9.jpg: 640x384 1 person, 61.6ms
# Speed: 1.0ms preprocess, 61.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 13, total_pred: 17, visible_pred: 13
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_015_jpg.rf.f9f4a2f961f83fa157ea9589e10e6ef9.jpg: 640x384 1 person, 63.0ms
# Speed: 1.2ms preprocess, 63.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 13, total_pred: 17, visible_pred: 13
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_016_jpg.rf.a61e7103d22003e613caff715cc2e6af.jpg: 640x384 1 person, 60.7ms
# Speed: 1.0ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_016_jpg.rf.a61e7103d22003e613caff715cc2e6af.jpg: 640x384 1 person, 71.7ms
# Speed: 1.1ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_016_jpg.rf.a61e7103d22003e613caff715cc2e6af.jpg: 640x384 1 person, 76.9ms
# Speed: 1.0ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_017_jpg.rf.122563551b80765ec9c83d234d55aa60.jpg: 640x384 1 person, 66.1ms
# Speed: 1.1ms preprocess, 66.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 81.81818181818183, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_017_jpg.rf.122563551b80765ec9c83d234d55aa60.jpg: 640x384 1 person, 69.3ms
# Speed: 1.1ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_017_jpg.rf.122563551b80765ec9c83d234d55aa60.jpg: 640x384 1 person, 61.2ms
# Speed: 1.1ms preprocess, 61.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_018_jpg.rf.89572f27131b84f8ab944e1f5d299838.jpg: 640x384 1 person, 59.7ms
# Speed: 1.0ms preprocess, 59.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_018_jpg.rf.89572f27131b84f8ab944e1f5d299838.jpg: 640x384 1 person, 65.9ms
# Speed: 1.1ms preprocess, 65.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_018_jpg.rf.89572f27131b84f8ab944e1f5d299838.jpg: 640x384 1 person, 60.3ms
# Speed: 1.1ms preprocess, 60.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_019_jpg.rf.1d44dd10c5ccd440fe9c42d687a33f78.jpg: 640x384 1 person, 60.0ms
# Speed: 1.1ms preprocess, 60.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_019_jpg.rf.1d44dd10c5ccd440fe9c42d687a33f78.jpg: 640x384 1 person, 59.2ms
# Speed: 0.9ms preprocess, 59.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_019_jpg.rf.1d44dd10c5ccd440fe9c42d687a33f78.jpg: 640x384 1 person, 59.2ms
# Speed: 1.0ms preprocess, 59.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_020_jpg.rf.9c03ec029de8f9b271b3e70f2460eb43.jpg: 640x384 1 person, 60.3ms
# Speed: 0.9ms preprocess, 60.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_020_jpg.rf.9c03ec029de8f9b271b3e70f2460eb43.jpg: 640x384 1 person, 58.8ms
# Speed: 1.0ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_020_jpg.rf.9c03ec029de8f9b271b3e70f2460eb43.jpg: 640x384 1 person, 59.9ms
# Speed: 1.2ms preprocess, 59.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_021_jpg.rf.d5d819dec165988997ada2c000f85db7.jpg: 640x384 1 person, 60.5ms
# Speed: 0.9ms preprocess, 60.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 88.88888888888889, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_021_jpg.rf.d5d819dec165988997ada2c000f85db7.jpg: 640x384 1 person, 62.3ms
# Speed: 1.0ms preprocess, 62.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_021_jpg.rf.d5d819dec165988997ada2c000f85db7.jpg: 640x384 1 person, 60.3ms
# Speed: 0.9ms preprocess, 60.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_022_jpg.rf.214ee4f4dda73001da2ce8300a2f4a67.jpg: 640x384 1 person, 60.8ms
# Speed: 1.0ms preprocess, 60.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_022_jpg.rf.214ee4f4dda73001da2ce8300a2f4a67.jpg: 640x384 1 person, 61.0ms
# Speed: 0.9ms preprocess, 61.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_022_jpg.rf.214ee4f4dda73001da2ce8300a2f4a67.jpg: 640x384 1 person, 61.2ms
# Speed: 1.0ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_023_jpg.rf.8f0cfbd8b70cadbb42b155858dcdb72b.jpg: 640x384 1 person, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_023_jpg.rf.8f0cfbd8b70cadbb42b155858dcdb72b.jpg: 640x384 1 person, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_023_jpg.rf.8f0cfbd8b70cadbb42b155858dcdb72b.jpg: 640x384 1 person, 59.8ms
# Speed: 0.9ms preprocess, 59.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_024_jpg.rf.9cad3999761a117ebea758d708d5d531.jpg: 640x384 1 person, 63.1ms
# Speed: 1.0ms preprocess, 63.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_024_jpg.rf.9cad3999761a117ebea758d708d5d531.jpg: 640x384 1 person, 59.1ms
# Speed: 1.0ms preprocess, 59.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_024_jpg.rf.9cad3999761a117ebea758d708d5d531.jpg: 640x384 1 person, 59.1ms
# Speed: 1.0ms preprocess, 59.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_025_jpg.rf.dd1e1b53eff2e467abc7dde760affdc4.jpg: 640x384 1 person, 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_025_jpg.rf.dd1e1b53eff2e467abc7dde760affdc4.jpg: 640x384 1 person, 60.7ms
# Speed: 1.1ms preprocess, 60.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_025_jpg.rf.dd1e1b53eff2e467abc7dde760affdc4.jpg: 640x384 1 person, 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_026_jpg.rf.851e25cc58b9f2a2d43793f77c1906fe.jpg: 640x384 1 person, 59.4ms
# Speed: 1.0ms preprocess, 59.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_026_jpg.rf.851e25cc58b9f2a2d43793f77c1906fe.jpg: 640x384 1 person, 58.4ms
# Speed: 1.1ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_026_jpg.rf.851e25cc58b9f2a2d43793f77c1906fe.jpg: 640x384 1 person, 60.5ms
# Speed: 1.0ms preprocess, 60.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_027_jpg.rf.3c0305eaebd7af92343d5a7a5c97e20c.jpg: 640x384 1 person, 60.8ms
# Speed: 1.0ms preprocess, 60.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_027_jpg.rf.3c0305eaebd7af92343d5a7a5c97e20c.jpg: 640x384 1 person, 60.7ms
# Speed: 1.1ms preprocess, 60.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_027_jpg.rf.3c0305eaebd7af92343d5a7a5c97e20c.jpg: 640x384 1 person, 60.3ms
# Speed: 1.0ms preprocess, 60.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_028_jpg.rf.b7b6281a45df236d7e3d2eb19c96b575.jpg: 640x384 1 person, 61.6ms
# Speed: 1.0ms preprocess, 61.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_028_jpg.rf.b7b6281a45df236d7e3d2eb19c96b575.jpg: 640x384 1 person, 104.3ms
# Speed: 1.0ms preprocess, 104.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_028_jpg.rf.b7b6281a45df236d7e3d2eb19c96b575.jpg: 640x384 1 person, 63.9ms
# Speed: 1.0ms preprocess, 63.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_029_jpg.rf.d8b47801f5d71941a9bec7ebcc64be98.jpg: 640x384 1 person, 62.9ms
# Speed: 0.9ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_029_jpg.rf.d8b47801f5d71941a9bec7ebcc64be98.jpg: 640x384 1 person, 64.5ms
# Speed: 1.0ms preprocess, 64.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_029_jpg.rf.d8b47801f5d71941a9bec7ebcc64be98.jpg: 640x384 1 person, 64.0ms
# Speed: 1.1ms preprocess, 64.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_030_jpg.rf.da5e9d05544f94084a2875e82c78fef5.jpg: 640x384 1 person, 62.7ms
# Speed: 1.0ms preprocess, 62.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 88.23529411764706, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_030_jpg.rf.da5e9d05544f94084a2875e82c78fef5.jpg: 640x384 1 person, 61.9ms
# Speed: 1.1ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_030_jpg.rf.da5e9d05544f94084a2875e82c78fef5.jpg: 640x384 1 person, 58.8ms
# Speed: 1.1ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_031_jpg.rf.d01ad07675500025673f27e8f15b67dd.jpg: 640x384 1 person, 60.3ms
# Speed: 1.0ms preprocess, 60.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 80.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_031_jpg.rf.d01ad07675500025673f27e8f15b67dd.jpg: 640x384 1 person, 60.2ms
# Speed: 1.0ms preprocess, 60.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_031_jpg.rf.d01ad07675500025673f27e8f15b67dd.jpg: 640x384 1 person, 63.3ms
# Speed: 0.9ms preprocess, 63.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_032_jpg.rf.b8b00062a3ef0404d4c8cb80377aa035.jpg: 640x384 1 person, 62.1ms
# Speed: 1.0ms preprocess, 62.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 90.9090909090909, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_032_jpg.rf.b8b00062a3ef0404d4c8cb80377aa035.jpg: 640x384 1 person, 62.5ms
# Speed: 1.0ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_032_jpg.rf.b8b00062a3ef0404d4c8cb80377aa035.jpg: 640x384 1 person, 62.9ms
# Speed: 1.0ms preprocess, 62.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_033_jpg.rf.7724586b779fee811c980439acc5edcb.jpg: 640x384 1 person, 65.4ms
# Speed: 1.0ms preprocess, 65.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 90.9090909090909, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_033_jpg.rf.7724586b779fee811c980439acc5edcb.jpg: 640x384 1 person, 64.5ms
# Speed: 1.0ms preprocess, 64.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_033_jpg.rf.7724586b779fee811c980439acc5edcb.jpg: 640x384 1 person, 62.5ms
# Speed: 0.9ms preprocess, 62.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_034_jpg.rf.39eb787eb373897e2b43cad66dd09652.jpg: 640x384 1 person, 63.7ms
# Speed: 1.1ms preprocess, 63.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_034_jpg.rf.39eb787eb373897e2b43cad66dd09652.jpg: 640x384 1 person, 60.6ms
# Speed: 1.0ms preprocess, 60.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_034_jpg.rf.39eb787eb373897e2b43cad66dd09652.jpg: 640x384 1 person, 62.4ms
# Speed: 1.0ms preprocess, 62.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_035_jpg.rf.0b77a8999db2010cee67cb50a23f19fe.jpg: 640x384 1 person, 61.3ms
# Speed: 1.1ms preprocess, 61.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_035_jpg.rf.0b77a8999db2010cee67cb50a23f19fe.jpg: 640x384 1 person, 84.0ms
# Speed: 1.3ms preprocess, 84.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_035_jpg.rf.0b77a8999db2010cee67cb50a23f19fe.jpg: 640x384 1 person, 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_036_jpg.rf.9905947b219a327992240e16e4cffe2e.jpg: 640x384 1 person, 60.6ms
# Speed: 1.0ms preprocess, 60.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 91.66666666666666, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_036_jpg.rf.9905947b219a327992240e16e4cffe2e.jpg: 640x384 1 person, 75.0ms
# Speed: 1.3ms preprocess, 75.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_036_jpg.rf.9905947b219a327992240e16e4cffe2e.jpg: 640x384 1 person, 78.5ms
# Speed: 1.2ms preprocess, 78.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_037_jpg.rf.997c4d474418759b01640e08dffd94b9.jpg: 640x384 1 person, 69.9ms
# Speed: 1.1ms preprocess, 69.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 90.9090909090909, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_037_jpg.rf.997c4d474418759b01640e08dffd94b9.jpg: 640x384 1 person, 72.7ms
# Speed: 1.2ms preprocess, 72.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_037_jpg.rf.997c4d474418759b01640e08dffd94b9.jpg: 640x384 1 person, 67.4ms
# Speed: 1.2ms preprocess, 67.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_038_jpg.rf.a021166000b1a12178949c06dc85d6bf.jpg: 640x384 1 person, 65.6ms
# Speed: 1.1ms preprocess, 65.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_038_jpg.rf.a021166000b1a12178949c06dc85d6bf.jpg: 640x384 1 person, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_038_jpg.rf.a021166000b1a12178949c06dc85d6bf.jpg: 640x384 1 person, 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_039_jpg.rf.9ac1db409b49ef60ce08d79ff1a30a48.jpg: 640x384 1 person, 62.6ms
# Speed: 1.2ms preprocess, 62.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_039_jpg.rf.9ac1db409b49ef60ce08d79ff1a30a48.jpg: 640x384 1 person, 68.9ms
# Speed: 1.0ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_039_jpg.rf.9ac1db409b49ef60ce08d79ff1a30a48.jpg: 640x384 1 person, 66.2ms
# Speed: 1.2ms preprocess, 66.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_040_jpg.rf.d710dd5ec7f87c241d380f2d9da1357b.jpg: 640x384 1 person, 62.1ms
# Speed: 1.0ms preprocess, 62.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_040_jpg.rf.d710dd5ec7f87c241d380f2d9da1357b.jpg: 640x384 1 person, 61.3ms
# Speed: 1.1ms preprocess, 61.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_040_jpg.rf.d710dd5ec7f87c241d380f2d9da1357b.jpg: 640x384 1 person, 60.9ms
# Speed: 0.9ms preprocess, 60.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_041_jpg.rf.11eb3a677e68ec76681752ea3a3dbf47.jpg: 640x384 1 person, 61.4ms
# Speed: 1.0ms preprocess, 61.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 15, total_pred: 17, visible_pred: 15
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_041_jpg.rf.11eb3a677e68ec76681752ea3a3dbf47.jpg: 640x384 1 person, 61.3ms
# Speed: 1.1ms preprocess, 61.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 15, total_pred: 17, visible_pred: 15
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_041_jpg.rf.11eb3a677e68ec76681752ea3a3dbf47.jpg: 640x384 1 person, 62.7ms
# Speed: 1.0ms preprocess, 62.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 15, total_pred: 17, visible_pred: 15
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_042_jpg.rf.a74fe8a0b48800340d2a64e414174c99.jpg: 640x384 1 person, 59.7ms
# Speed: 1.1ms preprocess, 59.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_042_jpg.rf.a74fe8a0b48800340d2a64e414174c99.jpg: 640x384 1 person, 63.3ms
# Speed: 1.1ms preprocess, 63.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_042_jpg.rf.a74fe8a0b48800340d2a64e414174c99.jpg: 640x384 1 person, 64.6ms
# Speed: 1.2ms preprocess, 64.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_043_jpg.rf.48f7666a8b703183e93c71017af8ede5.jpg: 640x384 1 person, 61.8ms
# Speed: 1.1ms preprocess, 61.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_043_jpg.rf.48f7666a8b703183e93c71017af8ede5.jpg: 640x384 1 person, 60.9ms
# Speed: 1.0ms preprocess, 60.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_043_jpg.rf.48f7666a8b703183e93c71017af8ede5.jpg: 640x384 1 person, 63.1ms
# Speed: 1.0ms preprocess, 63.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_044_jpg.rf.5dafc86c508894b71d5398319b032c77.jpg: 640x384 1 person, 63.5ms
# Speed: 1.1ms preprocess, 63.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 90.9090909090909, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_044_jpg.rf.5dafc86c508894b71d5398319b032c77.jpg: 640x384 1 person, 67.6ms
# Speed: 1.1ms preprocess, 67.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_044_jpg.rf.5dafc86c508894b71d5398319b032c77.jpg: 640x384 1 person, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_045_jpg.rf.740381672d954a588fb578615e7a9309.jpg: 640x384 1 person, 66.7ms
# Speed: 1.0ms preprocess, 66.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_045_jpg.rf.740381672d954a588fb578615e7a9309.jpg: 640x384 1 person, 61.9ms
# Speed: 1.0ms preprocess, 61.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_045_jpg.rf.740381672d954a588fb578615e7a9309.jpg: 640x384 1 person, 65.9ms
# Speed: 1.0ms preprocess, 65.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_046_jpg.rf.2e0fddc0b0396f4f8c7986335f618478.jpg: 640x384 1 person, 81.2ms
# Speed: 1.3ms preprocess, 81.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_046_jpg.rf.2e0fddc0b0396f4f8c7986335f618478.jpg: 640x384 1 person, 72.1ms
# Speed: 1.3ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# ...
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_056_jpg.rf.91fc7bd24e391c5dfb5b5ca3b36baeb1.jpg: 640x384 1 person, 62.9ms
# Speed: 0.8ms preprocess, 62.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_056_jpg.rf.91fc7bd24e391c5dfb5b5ca3b36baeb1.jpg: 640x384 1 person, 63.9ms
# Speed: 1.0ms preprocess, 63.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_057_jpg.rf.817ac3b1dd08c3eba3bf2ec27837e22f.jpg: 640x384 1 person, 65.3ms
# Speed: 1.0ms preprocess, 65.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_057_jpg.rf.817ac3b1dd08c3eba3bf2ec27837e22f.jpg: 640x384 1 person, 64.6ms
# Speed: 1.0ms preprocess, 64.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_057_jpg.rf.817ac3b1dd08c3eba3bf2ec27837e22f.jpg: 640x384 1 person, 64.2ms
# Speed: 1.1ms preprocess, 64.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_058_jpg.rf.1cdf5d501039211bebfc473751e5376d.jpg: 640x384 2 persons, 65.7ms
# Speed: 0.8ms preprocess, 65.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 80.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_058_jpg.rf.1cdf5d501039211bebfc473751e5376d.jpg: 640x384 2 persons, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_058_jpg.rf.1cdf5d501039211bebfc473751e5376d.jpg: 640x384 2 persons, 103.9ms
# Speed: 0.9ms preprocess, 103.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_059_jpg.rf.a2d57c5445e80715b121f5cf24192c9c.jpg: 640x384 1 person, 64.6ms
# Speed: 0.9ms preprocess, 64.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 90.9090909090909, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_059_jpg.rf.a2d57c5445e80715b121f5cf24192c9c.jpg: 640x384 1 person, 66.0ms
# Speed: 0.8ms preprocess, 66.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_059_jpg.rf.a2d57c5445e80715b121f5cf24192c9c.jpg: 640x384 1 person, 65.9ms
# Speed: 1.1ms preprocess, 65.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_060_jpg.rf.dc1483c88bd8fe66f0cd255f882c1145.jpg: 640x384 1 person, 64.2ms
# Speed: 1.0ms preprocess, 64.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_060_jpg.rf.dc1483c88bd8fe66f0cd255f882c1145.jpg: 640x384 1 person, 65.1ms
# Speed: 1.0ms preprocess, 65.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_060_jpg.rf.dc1483c88bd8fe66f0cd255f882c1145.jpg: 640x384 1 person, 64.7ms
# Speed: 1.0ms preprocess, 64.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_061_jpg.rf.fd75b94ddd3e3dc0c8bcc131c16abba8.jpg: 640x384 1 person, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_061_jpg.rf.fd75b94ddd3e3dc0c8bcc131c16abba8.jpg: 640x384 1 person, 63.2ms
# Speed: 1.0ms preprocess, 63.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_061_jpg.rf.fd75b94ddd3e3dc0c8bcc131c16abba8.jpg: 640x384 1 person, 64.2ms
# Speed: 0.8ms preprocess, 64.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg: 640x384 2 persons, 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 80.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg: 640x384 2 persons, 65.4ms
# Speed: 1.0ms preprocess, 65.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg: 640x384 2 persons, 61.6ms
# Speed: 1.0ms preprocess, 61.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_063_jpg.rf.6e6053f78c39006d4f4201702e4d78b4.jpg: 640x384 1 person, 62.5ms
# Speed: 1.0ms preprocess, 62.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 83.33333333333334, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_063_jpg.rf.6e6053f78c39006d4f4201702e4d78b4.jpg: 640x384 1 person, 66.3ms
# Speed: 1.0ms preprocess, 66.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_063_jpg.rf.6e6053f78c39006d4f4201702e4d78b4.jpg: 640x384 1 person, 64.5ms
# Speed: 0.9ms preprocess, 64.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 12, total_pred: 17, visible_pred: 12
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_064_jpg.rf.ea8838306055587be1482e596deab216.jpg: 640x384 1 person, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_064_jpg.rf.ea8838306055587be1482e596deab216.jpg: 640x384 1 person, 64.3ms
# Speed: 0.9ms preprocess, 64.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_064_jpg.rf.ea8838306055587be1482e596deab216.jpg: 640x384 1 person, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 10, total_pred: 17, visible_pred: 10
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_065_jpg.rf.939388d8bd5206439fbf96ec0ef0381e.jpg: 640x384 1 person, 62.9ms
# Speed: 1.0ms preprocess, 62.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 93.33333333333333, total_true: 17, visible_true: 15, total_pred: 17, visible_pred: 15
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_065_jpg.rf.939388d8bd5206439fbf96ec0ef0381e.jpg: 640x384 1 person, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 15, total_pred: 17, visible_pred: 15
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_065_jpg.rf.939388d8bd5206439fbf96ec0ef0381e.jpg: 640x384 1 person, 68.8ms
# Speed: 1.0ms preprocess, 68.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 15, total_pred: 17, visible_pred: 15
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_066_jpg.rf.17f44222fd8fc08c7e920cb371da4ba0.jpg: 640x384 1 person, 66.8ms
# Speed: 1.1ms preprocess, 66.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_066_jpg.rf.17f44222fd8fc08c7e920cb371da4ba0.jpg: 640x384 1 person, 63.9ms
# Speed: 0.8ms preprocess, 63.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_066_jpg.rf.17f44222fd8fc08c7e920cb371da4ba0.jpg: 640x384 1 person, 63.7ms
# Speed: 1.0ms preprocess, 63.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 17, total_pred: 17, visible_pred: 17
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_067_jpg.rf.9ef8934633f4efe45fc6533c76d43dd1.jpg: 640x384 1 person, 107.6ms
# Speed: 1.0ms preprocess, 107.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_067_jpg.rf.9ef8934633f4efe45fc6533c76d43dd1.jpg: 640x384 1 person, 67.3ms
# Speed: 1.1ms preprocess, 67.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_067_jpg.rf.9ef8934633f4efe45fc6533c76d43dd1.jpg: 640x384 1 person, 66.3ms
# Speed: 1.2ms preprocess, 66.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_068_jpg.rf.a0163dc53b078bf36d416ca848df5310.jpg: 640x384 1 person, 67.4ms
# Speed: 0.9ms preprocess, 67.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 77.77777777777779, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_068_jpg.rf.a0163dc53b078bf36d416ca848df5310.jpg: 640x384 1 person, 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_068_jpg.rf.a0163dc53b078bf36d416ca848df5310.jpg: 640x384 1 person, 66.8ms
# Speed: 0.9ms preprocess, 66.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_069_jpg.rf.a2c90562d71acb19864f20e6b19b7dd1.jpg: 640x384 1 person, 66.1ms
# Speed: 1.0ms preprocess, 66.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_069_jpg.rf.a2c90562d71acb19864f20e6b19b7dd1.jpg: 640x384 1 person, 65.4ms
# Speed: 1.0ms preprocess, 65.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_069_jpg.rf.a2c90562d71acb19864f20e6b19b7dd1.jpg: 640x384 1 person, 64.7ms
# Speed: 1.0ms preprocess, 64.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 11, total_pred: 17, visible_pred: 11
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_070_jpg.rf.60568a1aaf63e10d83beb3cee8603b0a.jpg: 640x384 1 person, 64.4ms
# Speed: 1.0ms preprocess, 64.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 77.77777777777779, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_070_jpg.rf.60568a1aaf63e10d83beb3cee8603b0a.jpg: 640x384 1 person, 62.6ms
# Speed: 1.1ms preprocess, 62.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9
#
# image 1/1 /Users/apple/Documents/pose_estimation/dataset/images/imagen_070_jpg.rf.60568a1aaf63e10d83beb3cee8603b0a.jpg: 640x384 1 person, 64.5ms
# Speed: 1.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/pose/predict3
# pck: 100.0, total_true: 17, visible_true: 9, total_pred: 17, visible_pred: 9

# %% [markdown]
# # Generando el XLS

# %%
# Crear un DataFrame con los resultados
df_results = pd.DataFrame(results)
output_excel_path = os.path.join(os.getenv('BASE_PATH'), os.getenv('YOLO_SUBPATH'), 'precision', 'PCK', 'yolov11_pck_results.xlsx')
df_results.to_excel(output_excel_path, index=False, engine='openpyxl')

print(f"Los resultados se han guardado en {output_excel_path}")
# Out:
# Los resultados se han guardado en /Users/apple/Documents/pose_estimation/YOLOv11/precision/PCK/yolov11_pck_results.xlsx
