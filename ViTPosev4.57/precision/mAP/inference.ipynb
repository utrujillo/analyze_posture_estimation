# %%
import os
import importlib , mAP, pandas as pd # Importar importlib para recargar módulos
from dotenv import load_dotenv

dotenv_path = os.path.join(os.getcwd(), '..', '.env')
importlib.reload(mAP)
from mAP import mAP

# Configuracion
detector_path = os.path.join(os.getenv('BASE_PATH'), os.getenv('VITPOSE_SUBPATH'), os.getenv('DETECTOR_SUBPATH'))
estimator_path = os.path.join(os.getenv('BASE_PATH'), os.getenv('VITPOSE_SUBPATH'), os.getenv('POSE_SUBPATH'))
images_path = os.path.join(os.getenv('BASE_PATH'), os.getenv('IMAGES_SUBPATH'))
labels_path = os.path.join(os.getenv('BASE_PATH'), os.getenv('LABELS_SUBPATH'))
evaluator = mAP(os.getenv('BASE_PATH'), images_path, labels_path, detector_path, estimator_path)
thresholds = [0.1, 0.5, 0.9]
# Out:
# Cargando modelos en el dispositivo: cpu
# `use_fast` is set to `True` but the image processor class does not have a fast version.  Falling back to the slow version.

# %% [markdown]
# # Evaluar una imagen

# %%
image = 'imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg'
# image = 'imagen_011_jpg.rf.efc4f6570869d250cc6316a35f6b4b26.jpg'
results = []
for threshold in thresholds:
    results = evaluator.evaluate_image(image, threshold, results)
# Out:
# Imagen: imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 10, false_positives: 7,           false_negatives: 7, recall: 0.5882352941176471, ap: 0.5882352941176471

# %% [markdown]
# # Evaluar multiples imagenes

# %%
# Obtener la lista de todas las imágenes en la carpeta
image_files = [f for f in os.listdir(images_path) if f.endswith('.jpg')]
image_files_sorted = sorted(image_files)
results = []

for image in image_files_sorted:
    for threshold in thresholds:
        results = evaluator.evaluate_image(image, threshold, results)
# Out:
# Imagen: imagen_002_jpg.rf.39766b197a04d8d1569b3e546fd07390.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_002_jpg.rf.39766b197a04d8d1569b3e546fd07390.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_002_jpg.rf.39766b197a04d8d1569b3e546fd07390.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_003_jpg.rf.212077a70b1de84df04262b03db57f65.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_003_jpg.rf.212077a70b1de84df04262b03db57f65.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_003_jpg.rf.212077a70b1de84df04262b03db57f65.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_004_jpg.rf.4989fa64a1816f9648b130cd037da4c0.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_004_jpg.rf.4989fa64a1816f9648b130cd037da4c0.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_004_jpg.rf.4989fa64a1816f9648b130cd037da4c0.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_005_jpg.rf.6fa127bc74f8ab541befa56df6976a55.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_005_jpg.rf.6fa127bc74f8ab541befa56df6976a55.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_005_jpg.rf.6fa127bc74f8ab541befa56df6976a55.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_006_jpg.rf.f9e4e2609ee3c557ed403d37504f89bf.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 10, false_positives: 7,           false_negatives: 7, recall: 0.5882352941176471, ap: 0.5882352941176471
# Imagen: imagen_007_jpg.rf.427bc5600e403e5fbbab27a114f10306.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_007_jpg.rf.427bc5600e403e5fbbab27a114f10306.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_007_jpg.rf.427bc5600e403e5fbbab27a114f10306.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_008_jpg.rf.00700f922d37da70606fa16130a5d9a7.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_008_jpg.rf.00700f922d37da70606fa16130a5d9a7.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_008_jpg.rf.00700f922d37da70606fa16130a5d9a7.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_009_jpg.rf.edc93a9e00958f5569e22157b0aefe83.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_009_jpg.rf.edc93a9e00958f5569e22157b0aefe83.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_009_jpg.rf.edc93a9e00958f5569e22157b0aefe83.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_010_jpg.rf.adf365bd7315f99371253648fc784b87.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_010_jpg.rf.adf365bd7315f99371253648fc784b87.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_010_jpg.rf.adf365bd7315f99371253648fc784b87.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_011_jpg.rf.efc4f6570869d250cc6316a35f6b4b26.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_011_jpg.rf.efc4f6570869d250cc6316a35f6b4b26.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_011_jpg.rf.efc4f6570869d250cc6316a35f6b4b26.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_012_jpg.rf.73579363caeccc19c4ce66fcc36a6b35.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_012_jpg.rf.73579363caeccc19c4ce66fcc36a6b35.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_012_jpg.rf.73579363caeccc19c4ce66fcc36a6b35.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_013_jpg.rf.d8bbed7435222a80c55481d03c35ed33.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_013_jpg.rf.d8bbed7435222a80c55481d03c35ed33.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_013_jpg.rf.d8bbed7435222a80c55481d03c35ed33.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_014_jpg.rf.9b73844fd1a58e6de1dd2cd81aca8dc6.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_014_jpg.rf.9b73844fd1a58e6de1dd2cd81aca8dc6.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_014_jpg.rf.9b73844fd1a58e6de1dd2cd81aca8dc6.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_015_jpg.rf.f9f4a2f961f83fa157ea9589e10e6ef9.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_015_jpg.rf.f9f4a2f961f83fa157ea9589e10e6ef9.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_015_jpg.rf.f9f4a2f961f83fa157ea9589e10e6ef9.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_016_jpg.rf.a61e7103d22003e613caff715cc2e6af.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_016_jpg.rf.a61e7103d22003e613caff715cc2e6af.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_016_jpg.rf.a61e7103d22003e613caff715cc2e6af.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_017_jpg.rf.122563551b80765ec9c83d234d55aa60.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_017_jpg.rf.122563551b80765ec9c83d234d55aa60.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_017_jpg.rf.122563551b80765ec9c83d234d55aa60.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_018_jpg.rf.89572f27131b84f8ab944e1f5d299838.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_018_jpg.rf.89572f27131b84f8ab944e1f5d299838.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_018_jpg.rf.89572f27131b84f8ab944e1f5d299838.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_019_jpg.rf.1d44dd10c5ccd440fe9c42d687a33f78.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 16, true_positives: 16, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_019_jpg.rf.1d44dd10c5ccd440fe9c42d687a33f78.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 16, true_positives: 16, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_019_jpg.rf.1d44dd10c5ccd440fe9c42d687a33f78.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 16, true_positives: 12, false_positives: 4,           false_negatives: 4, recall: 0.75, ap: 0.75
# Imagen: imagen_020_jpg.rf.9c03ec029de8f9b271b3e70f2460eb43.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_020_jpg.rf.9c03ec029de8f9b271b3e70f2460eb43.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_020_jpg.rf.9c03ec029de8f9b271b3e70f2460eb43.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_021_jpg.rf.d5d819dec165988997ada2c000f85db7.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 15, true_positives: 15, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_021_jpg.rf.d5d819dec165988997ada2c000f85db7.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 15, true_positives: 15, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_021_jpg.rf.d5d819dec165988997ada2c000f85db7.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 15, true_positives: 11, false_positives: 4,           false_negatives: 4, recall: 0.7333333333333333, ap: 0.7333333333333333
# Imagen: imagen_022_jpg.rf.214ee4f4dda73001da2ce8300a2f4a67.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_022_jpg.rf.214ee4f4dda73001da2ce8300a2f4a67.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_022_jpg.rf.214ee4f4dda73001da2ce8300a2f4a67.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_023_jpg.rf.8f0cfbd8b70cadbb42b155858dcdb72b.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_023_jpg.rf.8f0cfbd8b70cadbb42b155858dcdb72b.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_023_jpg.rf.8f0cfbd8b70cadbb42b155858dcdb72b.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_024_jpg.rf.9cad3999761a117ebea758d708d5d531.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_024_jpg.rf.9cad3999761a117ebea758d708d5d531.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_024_jpg.rf.9cad3999761a117ebea758d708d5d531.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_025_jpg.rf.dd1e1b53eff2e467abc7dde760affdc4.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_025_jpg.rf.dd1e1b53eff2e467abc7dde760affdc4.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_025_jpg.rf.dd1e1b53eff2e467abc7dde760affdc4.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_026_jpg.rf.851e25cc58b9f2a2d43793f77c1906fe.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_026_jpg.rf.851e25cc58b9f2a2d43793f77c1906fe.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_026_jpg.rf.851e25cc58b9f2a2d43793f77c1906fe.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 10, false_positives: 7,           false_negatives: 7, recall: 0.5882352941176471, ap: 0.5882352941176471
# Imagen: imagen_027_jpg.rf.3c0305eaebd7af92343d5a7a5c97e20c.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_027_jpg.rf.3c0305eaebd7af92343d5a7a5c97e20c.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_027_jpg.rf.3c0305eaebd7af92343d5a7a5c97e20c.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_028_jpg.rf.b7b6281a45df236d7e3d2eb19c96b575.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_028_jpg.rf.b7b6281a45df236d7e3d2eb19c96b575.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_028_jpg.rf.b7b6281a45df236d7e3d2eb19c96b575.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_029_jpg.rf.d8b47801f5d71941a9bec7ebcc64be98.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_029_jpg.rf.d8b47801f5d71941a9bec7ebcc64be98.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_029_jpg.rf.d8b47801f5d71941a9bec7ebcc64be98.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_030_jpg.rf.da5e9d05544f94084a2875e82c78fef5.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_030_jpg.rf.da5e9d05544f94084a2875e82c78fef5.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_030_jpg.rf.da5e9d05544f94084a2875e82c78fef5.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_031_jpg.rf.d01ad07675500025673f27e8f15b67dd.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_031_jpg.rf.d01ad07675500025673f27e8f15b67dd.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_031_jpg.rf.d01ad07675500025673f27e8f15b67dd.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_032_jpg.rf.b8b00062a3ef0404d4c8cb80377aa035.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_032_jpg.rf.b8b00062a3ef0404d4c8cb80377aa035.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_032_jpg.rf.b8b00062a3ef0404d4c8cb80377aa035.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_033_jpg.rf.7724586b779fee811c980439acc5edcb.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_033_jpg.rf.7724586b779fee811c980439acc5edcb.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_033_jpg.rf.7724586b779fee811c980439acc5edcb.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_034_jpg.rf.39eb787eb373897e2b43cad66dd09652.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_034_jpg.rf.39eb787eb373897e2b43cad66dd09652.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_034_jpg.rf.39eb787eb373897e2b43cad66dd09652.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_035_jpg.rf.0b77a8999db2010cee67cb50a23f19fe.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_035_jpg.rf.0b77a8999db2010cee67cb50a23f19fe.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_035_jpg.rf.0b77a8999db2010cee67cb50a23f19fe.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_036_jpg.rf.9905947b219a327992240e16e4cffe2e.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_036_jpg.rf.9905947b219a327992240e16e4cffe2e.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_036_jpg.rf.9905947b219a327992240e16e4cffe2e.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_037_jpg.rf.997c4d474418759b01640e08dffd94b9.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_037_jpg.rf.997c4d474418759b01640e08dffd94b9.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_037_jpg.rf.997c4d474418759b01640e08dffd94b9.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_038_jpg.rf.a021166000b1a12178949c06dc85d6bf.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_038_jpg.rf.a021166000b1a12178949c06dc85d6bf.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_038_jpg.rf.a021166000b1a12178949c06dc85d6bf.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 10, false_positives: 7,           false_negatives: 7, recall: 0.5882352941176471, ap: 0.5882352941176471
# Imagen: imagen_039_jpg.rf.9ac1db409b49ef60ce08d79ff1a30a48.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_039_jpg.rf.9ac1db409b49ef60ce08d79ff1a30a48.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_039_jpg.rf.9ac1db409b49ef60ce08d79ff1a30a48.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_040_jpg.rf.d710dd5ec7f87c241d380f2d9da1357b.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_040_jpg.rf.d710dd5ec7f87c241d380f2d9da1357b.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_040_jpg.rf.d710dd5ec7f87c241d380f2d9da1357b.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_041_jpg.rf.11eb3a677e68ec76681752ea3a3dbf47.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_041_jpg.rf.11eb3a677e68ec76681752ea3a3dbf47.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_041_jpg.rf.11eb3a677e68ec76681752ea3a3dbf47.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_042_jpg.rf.a74fe8a0b48800340d2a64e414174c99.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_042_jpg.rf.a74fe8a0b48800340d2a64e414174c99.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_042_jpg.rf.a74fe8a0b48800340d2a64e414174c99.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_043_jpg.rf.48f7666a8b703183e93c71017af8ede5.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_043_jpg.rf.48f7666a8b703183e93c71017af8ede5.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_043_jpg.rf.48f7666a8b703183e93c71017af8ede5.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 10, false_positives: 7,           false_negatives: 7, recall: 0.5882352941176471, ap: 0.5882352941176471
# Imagen: imagen_044_jpg.rf.5dafc86c508894b71d5398319b032c77.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 16, true_positives: 16, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_044_jpg.rf.5dafc86c508894b71d5398319b032c77.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 16, true_positives: 16, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_044_jpg.rf.5dafc86c508894b71d5398319b032c77.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 16, true_positives: 13, false_positives: 3,           false_negatives: 3, recall: 0.8125, ap: 0.8125
# Imagen: imagen_045_jpg.rf.740381672d954a588fb578615e7a9309.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_045_jpg.rf.740381672d954a588fb578615e7a9309.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_045_jpg.rf.740381672d954a588fb578615e7a9309.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_046_jpg.rf.2e0fddc0b0396f4f8c7986335f618478.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_046_jpg.rf.2e0fddc0b0396f4f8c7986335f618478.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_046_jpg.rf.2e0fddc0b0396f4f8c7986335f618478.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_047_jpg.rf.3b9b9d7cea0263619730ac88080552d3.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_047_jpg.rf.3b9b9d7cea0263619730ac88080552d3.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_047_jpg.rf.3b9b9d7cea0263619730ac88080552d3.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_048_jpg.rf.a8aba5d7117f1601a363c89ba10667d0.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_048_jpg.rf.a8aba5d7117f1601a363c89ba10667d0.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_048_jpg.rf.a8aba5d7117f1601a363c89ba10667d0.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_049_jpg.rf.b73da4e6df97e30e7591bb4db61a2005.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_049_jpg.rf.b73da4e6df97e30e7591bb4db61a2005.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_049_jpg.rf.b73da4e6df97e30e7591bb4db61a2005.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_050_jpg.rf.90b9aab729a8161d81784b429b40743a.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_050_jpg.rf.90b9aab729a8161d81784b429b40743a.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_050_jpg.rf.90b9aab729a8161d81784b429b40743a.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_051_jpg.rf.ef9804b7653e74f31c13dd8db40f15da.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_051_jpg.rf.ef9804b7653e74f31c13dd8db40f15da.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_051_jpg.rf.ef9804b7653e74f31c13dd8db40f15da.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_052_jpg.rf.99e4505426b30cc5add575c69ec73da2.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_052_jpg.rf.99e4505426b30cc5add575c69ec73da2.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_052_jpg.rf.99e4505426b30cc5add575c69ec73da2.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 9, false_positives: 8,           false_negatives: 8, recall: 0.5294117647058824, ap: 0.5294117647058824
# Imagen: imagen_053_jpg.rf.8585d5035131f411da878c525557ed28.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_053_jpg.rf.8585d5035131f411da878c525557ed28.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_053_jpg.rf.8585d5035131f411da878c525557ed28.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_054_jpg.rf.41be28c49231a6247b5cd2261b08f1de.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_054_jpg.rf.41be28c49231a6247b5cd2261b08f1de.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_054_jpg.rf.41be28c49231a6247b5cd2261b08f1de.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_055_jpg.rf.ef20a97116f6eaaf570f22deca14a568.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_055_jpg.rf.ef20a97116f6eaaf570f22deca14a568.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_055_jpg.rf.ef20a97116f6eaaf570f22deca14a568.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_056_jpg.rf.91fc7bd24e391c5dfb5b5ca3b36baeb1.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_056_jpg.rf.91fc7bd24e391c5dfb5b5ca3b36baeb1.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_056_jpg.rf.91fc7bd24e391c5dfb5b5ca3b36baeb1.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_057_jpg.rf.817ac3b1dd08c3eba3bf2ec27837e22f.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_057_jpg.rf.817ac3b1dd08c3eba3bf2ec27837e22f.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_057_jpg.rf.817ac3b1dd08c3eba3bf2ec27837e22f.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 10, false_positives: 7,           false_negatives: 7, recall: 0.5882352941176471, ap: 0.5882352941176471
# Imagen: imagen_058_jpg.rf.1cdf5d501039211bebfc473751e5376d.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_058_jpg.rf.1cdf5d501039211bebfc473751e5376d.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_058_jpg.rf.1cdf5d501039211bebfc473751e5376d.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_059_jpg.rf.a2d57c5445e80715b121f5cf24192c9c.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_059_jpg.rf.a2d57c5445e80715b121f5cf24192c9c.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_059_jpg.rf.a2d57c5445e80715b121f5cf24192c9c.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_060_jpg.rf.dc1483c88bd8fe66f0cd255f882c1145.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_060_jpg.rf.dc1483c88bd8fe66f0cd255f882c1145.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_060_jpg.rf.dc1483c88bd8fe66f0cd255f882c1145.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_061_jpg.rf.fd75b94ddd3e3dc0c8bcc131c16abba8.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_061_jpg.rf.fd75b94ddd3e3dc0c8bcc131c16abba8.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_061_jpg.rf.fd75b94ddd3e3dc0c8bcc131c16abba8.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 10, false_positives: 7,           false_negatives: 7, recall: 0.5882352941176471, ap: 0.5882352941176471
# Imagen: imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 14, false_positives: 3,           false_negatives: 3, recall: 0.8235294117647058, ap: 0.8235294117647058
# Imagen: imagen_062_jpg.rf.67b212e193dcccad590e8a4eb2dc24cc.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 10, false_positives: 7,           false_negatives: 7, recall: 0.5882352941176471, ap: 0.5882352941176471
# Imagen: imagen_063_jpg.rf.6e6053f78c39006d4f4201702e4d78b4.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_063_jpg.rf.6e6053f78c39006d4f4201702e4d78b4.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_063_jpg.rf.6e6053f78c39006d4f4201702e4d78b4.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 13, false_positives: 4,           false_negatives: 4, recall: 0.7647058823529411, ap: 0.7647058823529411
# Imagen: imagen_064_jpg.rf.ea8838306055587be1482e596deab216.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_064_jpg.rf.ea8838306055587be1482e596deab216.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_064_jpg.rf.ea8838306055587be1482e596deab216.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_065_jpg.rf.939388d8bd5206439fbf96ec0ef0381e.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_065_jpg.rf.939388d8bd5206439fbf96ec0ef0381e.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_065_jpg.rf.939388d8bd5206439fbf96ec0ef0381e.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_066_jpg.rf.17f44222fd8fc08c7e920cb371da4ba0.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_066_jpg.rf.17f44222fd8fc08c7e920cb371da4ba0.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_066_jpg.rf.17f44222fd8fc08c7e920cb371da4ba0.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_067_jpg.rf.9ef8934633f4efe45fc6533c76d43dd1.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_067_jpg.rf.9ef8934633f4efe45fc6533c76d43dd1.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_067_jpg.rf.9ef8934633f4efe45fc6533c76d43dd1.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 11, false_positives: 6,           false_negatives: 6, recall: 0.6470588235294118, ap: 0.6470588235294118
# Imagen: imagen_068_jpg.rf.a0163dc53b078bf36d416ca848df5310.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 15, true_positives: 14, false_positives: 1,           false_negatives: 1, recall: 0.9333333333333333, ap: 0.9333333333333333
# Imagen: imagen_068_jpg.rf.a0163dc53b078bf36d416ca848df5310.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 15, true_positives: 14, false_positives: 1,           false_negatives: 1, recall: 0.9333333333333333, ap: 0.9333333333333333
# Imagen: imagen_068_jpg.rf.a0163dc53b078bf36d416ca848df5310.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 15, true_positives: 12, false_positives: 3,           false_negatives: 3, recall: 0.8, ap: 0.8
# Imagen: imagen_069_jpg.rf.a2c90562d71acb19864f20e6b19b7dd1.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_069_jpg.rf.a2c90562d71acb19864f20e6b19b7dd1.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 15, false_positives: 2,           false_negatives: 2, recall: 0.8823529411764706, ap: 0.8823529411764706
# Imagen: imagen_069_jpg.rf.a2c90562d71acb19864f20e6b19b7dd1.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765
# Imagen: imagen_070_jpg.rf.60568a1aaf63e10d83beb3cee8603b0a.jpg, threshold: 0.1, true_keypoints: 17,           num_visible: 17, true_positives: 17, false_positives: 0,           false_negatives: 0, recall: 1.0, ap: 1.0
# Imagen: imagen_070_jpg.rf.60568a1aaf63e10d83beb3cee8603b0a.jpg, threshold: 0.5, true_keypoints: 17,           num_visible: 17, true_positives: 16, false_positives: 1,           false_negatives: 1, recall: 0.9411764705882353, ap: 0.9411764705882353
# Imagen: imagen_070_jpg.rf.60568a1aaf63e10d83beb3cee8603b0a.jpg, threshold: 0.9, true_keypoints: 17,           num_visible: 17, true_positives: 12, false_positives: 5,           false_negatives: 5, recall: 0.7058823529411765, ap: 0.7058823529411765

# %% [markdown]
# # Generamos el XLS con los resultados

# %%
# Crear un DataFrame con los resultados
df_results = pd.DataFrame(results)
output_excel_path = os.path.join(os.getenv('BASE_PATH'), os.getenv('VITPOSE_SUBPATH'), 'precision', 'mAP', 'vitpose_mAP_results.xlsx')
df_results.to_excel(output_excel_path, index=False, engine='openpyxl')

print(f"Los resultados se han guardado en {output_excel_path}")
# Out:
# Los resultados se han guardado en /Users/apple/Documents/pose_estimation/ViTPosev4.57/precision/mAP/vitpose_mAP_results.xlsx
